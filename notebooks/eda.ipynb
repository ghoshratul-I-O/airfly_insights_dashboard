# %% [markdown]
# Loading the raw data set

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/flights.csv")
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# 0      1400     5      15  2013-01-01 05:00:00   United Air Lines Inc.
# 1      1416     5      29  2013-01-01 05:00:00   United Air Lines Inc.
# 2      1089     5      40  2013-01-01 05:00:00  American Airlines Inc.
# 3      1576     5      45  2013-01-01 05:00:00         JetBlue Airways
# 4       762     6       0  2013-01-01 06:00:00    Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %% [markdown]
# Checking the memory usage before optimization

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
#  16  distance        336776 non-null  int64
#  17  hour            336776 non-null  int64
#  18  minute          336776 non-null  int64
#  19  time_hour       336776 non-null  object
#  20  name            336776 non-null  object
# dtypes: float64(5), int64(10), object(6)
# memory usage: 149.6 MB

# %% [markdown]
# Optimization

# %% [markdown]
# Converting to category

# %%
categorical_cols = ['carrier', 'origin', 'dest', 'tailnum', 'name']
for col in categorical_cols:
    df[col] = df[col].astype('category')

# %% [markdown]
# Downcasting integer columns

# %%
df['year'] = df['year'].astype('int16')
df['month'] = df['month'].astype('int8')
df['day'] =  df['day'].astype('int8')
df['hour'] = df['hour'].astype('int8')
df['minute'] = df['minute'].astype('int8')
df['distance'] = df['distance'].astype('int16')

# %% [markdown]
# Downcasting floats

# %%
df['dep_delay'] = pd.to_numeric(df['dep_delay'], downcast='float')
df['arr_delay'] = pd.to_numeric(df['arr_delay'], downcast='float')
df['air_time'] = pd.to_numeric(df['air_time'], downcast='float')

# %% [markdown]
# Checking memory usage after optimization

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int16
#  2   month           336776 non-null  int8
#  3   day             336776 non-null  int8
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float32
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float32
#  10  carrier         336776 non-null  category
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  category
#  13  origin          336776 non-null  category
#  14  dest            336776 non-null  category
#  15  air_time        327346 non-null  float32
#  16  distance        336776 non-null  int16
#  17  hour            336776 non-null  int8
#  18  minute          336776 non-null  int8
#  19  time_hour       336776 non-null  object
#  20  name            336776 non-null  category
# dtypes: category(5), float32(3), float64(2), int16(2), int64(4), int8(4), object(1)
# memory usage: 46.0 MB

# %% [markdown]
# ### Before
#
# ###### dtypes: float64(5), int64(10), object(6)
#
# ###### memory usage: 149.6 MB
#
# ### After
#
# ###### dtypes: category(5), float32(3), float64(2), int16(2), int64(4), int8(4), object(1)
#
# ###### memory usage: 46.0 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int16
#  2   month           336776 non-null  int8
#  3   day             336776 non-null  int8
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float32
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float32
#  10  carrier         336776 non-null  category
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  category
#  13  origin          336776 non-null  category
#  14  dest            336776 non-null  category
#  15  air_time        327346 non-null  float32
#  16  distance        336776 non-null  int16
#  17  hour            336776 non-null  int8
#  18  minute          336776 non-null  int8
#  19  time_hour       336776 non-null  object
#  20  name            336776 non-null  category
# dtypes: category(5), float32(3), float64(2), int16(2), int64(4), int8(4), object(1)
# memory usage: 26.5+ MB

# %% [markdown]
# ### Cancelled Flag
#
# ##### 1 → Cancelled flight
# ##### 0 → Completed flight

# %%
df['cancelled'] = df['dep_time'].isna().astype(int)

# %% [markdown]
# ### Creating proper date column

# %%
df['flight_date'] = pd.to_datetime(df[['year', 'month', 'day']])

# %% [markdown]
# ### Day of week

# %%
df['day_of_week'] = df['flight_date'].dt.day_name()

# %% [markdown]
# ### Route column

# %%
df['route'] = df['origin'].astype(str) + "-" + df['dest'].astype(str)

# %% [markdown]
# ### On-Time indicator

# %%
df['on_time'] = (df['arr_delay'] <= 0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int16
#  2   month           336776 non-null  int8
#  3   day             336776 non-null  int8
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float32
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float32
#  10  carrier         336776 non-null  category
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  category
#  13  origin          336776 non-null  category
#  14  dest            336776 non-null  category
#  15  air_time        327346 non-null  float32
#  16  distance        336776 non-null  int16
#  17  hour            336776 non-null  int8
#  18  minute          336776 non-null  int8
#  19  time_hour       336776 non-null  object
#  20  name            336776 non-null  category
#  21  cancelled       336776 non-null  int64
#  22  flight_date     336776 non-null  datetime64[ns]
#  23  day_of_week     336776 non-null  object
#  24  route           336776 non-null  object
#  25  on_time         336776 non-null  int64
# dtypes: category(5), datetime64[ns](1), float32(3), float64(2), int16(2), int64(6), int8(4), object(3)
# memory usage: 39.3+ MB

# %%
df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name', 'cancelled', 'flight_date', 'day_of_week', 'route',
#        'on_time'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                         int64
# year                       int16
# month                       int8
# day                         int8
# dep_time                 float64
# sched_dep_time             int64
# dep_delay                float32
# arr_time                 float64
# sched_arr_time             int64
# arr_delay                float32
# carrier                 category
# flight                     int64
# tailnum                 category
# origin                  category
# dest                    category
# air_time                 float32
# distance                   int16
# hour                        int8
# minute                      int8
# time_hour                 object
# name                    category
# cancelled                  int64
# flight_date       datetime64[ns]
# day_of_week               object
# route                     object
# on_time                    int64
# dtype: object

# %% [markdown]
# ### Checking Missing Values for Cancelled Flights

# %%
df[df['cancelled'] == 1][['dep_time','arr_delay']].head()
# Out:
#       dep_time  arr_delay
# 838        NaN        NaN
# 839        NaN        NaN
# 840        NaN        NaN
# 841        NaN        NaN
# 1777       NaN        NaN

# %% [markdown]
# ### Checking On-Time Flag Against Arrival Delay

# %%
df[['arr_delay','on_time']].sample(10)
# Out:
#         arr_delay  on_time
# 35482       -23.0        1
# 59733         7.0        0
# 275922      -19.0        1
# 184196        4.0        0
# 80118        50.0        0
# 122201       77.0        0
# 148450      -13.0        1
# 265217       34.0        0
# 102574       -3.0        1
# 32877        -6.0        1

# %% [markdown]
# ### Checking for Non-Cancelled Flights with Missing arr_delay

# %%
df[(df['cancelled'] == 0) & (df['arr_delay'].isna())]
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 471        471  2013      1    1    1525.0            1530       -5.0
# 477        477  2013      1    1    1528.0            1459       29.0
# 615        615  2013      1    1    1740.0            1745       -5.0
# 643        643  2013      1    1    1807.0            1738       29.0
# 725        725  2013      1    1    1939.0            1840       59.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 334354  334354  2013      9   28     847.0             839        8.0
# 334412  334412  2013      9   28    1010.0            1020      -10.0
# 334495  334495  2013      9   28    1214.0            1225      -11.0
# 335534  335534  2013      9   29    1734.0            1711       23.0
# 335805  335805  2013      9   30     559.0             600       -1.0
#
#         arr_time  sched_arr_time  arr_delay  ... distance  hour minute  \
# 471       1934.0            1805        NaN  ...     1147    15     30
# 477       2002.0            1647        NaN  ...      872    14     59
# 615       2158.0            2020        NaN  ...     1147    17     45
# 643       2251.0            2103        NaN  ...     2425    17     38
# 725         29.0            2151        NaN  ...     1391    18     40
# ...          ...             ...        ...  ...      ...   ...    ...
# 334354    1130.0             959        NaN  ...      725     8     39
# 334412    1344.0            1222        NaN  ...     1017    10     20
# 334495    1801.0            1510        NaN  ...     1372    12     25
# 335534    2159.0            2020        NaN  ...     2434    17     11
# 335805       NaN             715        NaN  ...      711     6      0
#
#                   time_hour                      name  cancelled  flight_date  \
# 471     2013-01-01 15:00:00                 Envoy Air          0   2013-01-01
# 477     2013-01-01 14:00:00  ExpressJet Airlines Inc.          0   2013-01-01
# 615     2013-01-01 17:00:00                 Envoy Air          0   2013-01-01
# 643     2013-01-01 17:00:00     United Air Lines Inc.          0   2013-01-01
# 725     2013-01-01 18:00:00         Endeavor Air Inc.          0   2013-01-01
# ...                     ...                       ...        ...          ...
# 334354  2013-09-28 08:00:00  ExpressJet Airlines Inc.          0   2013-09-28
# 334412  2013-09-28 10:00:00  ExpressJet Airlines Inc.          0   2013-09-28
# 334495  2013-09-28 12:00:00    American Airlines Inc.          0   2013-09-28
# 335534  2013-09-29 17:00:00     United Air Lines Inc.          0   2013-09-29
# 335805  2013-09-30 06:00:00    Southwest Airlines Co.          0   2013-09-30
#
#         day_of_week    route on_time
# 471         Tuesday  LGA-XNA       0
# 477         Tuesday  EWR-STL       0
# 615         Tuesday  LGA-XNA       0
# 643         Tuesday  EWR-SAN       0
# 725         Tuesday  JFK-DFW       0
# ...             ...      ...     ...
# 334354     Saturday  EWR-MKE       0
# 334412     Saturday  EWR-DSM       0
# 334495     Saturday  EWR-DFW       0
# 335534       Sunday  EWR-PDX       0
# 335805       Monday  EWR-MDW       0
#
# [1175 rows x 26 columns]

# %% [markdown]
# ### Handling Missing Values in Arrival Delay Column

# %%
df = df.dropna(subset=['arr_delay'])

# %%
df.shape
# Out:
# (327346, 26)

# %% [markdown]
# ### Verifying That There Are No Missing Values in arr_delay

# %%
df['arr_delay'].isna().sum()
# Out:
# np.int64(0)

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327346 entries, 0 to 336769
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              327346 non-null  int64
#  1   year            327346 non-null  int16
#  2   month           327346 non-null  int8
#  3   day             327346 non-null  int8
#  4   dep_time        327346 non-null  float64
#  5   sched_dep_time  327346 non-null  int64
#  6   dep_delay       327346 non-null  float32
#  7   arr_time        327346 non-null  float64
#  8   sched_arr_time  327346 non-null  int64
#  9   arr_delay       327346 non-null  float32
#  10  carrier         327346 non-null  category
#  11  flight          327346 non-null  int64
#  12  tailnum         327346 non-null  category
#  13  origin          327346 non-null  category
#  14  dest            327346 non-null  category
#  15  air_time        327346 non-null  float32
#  16  distance        327346 non-null  int16
#  17  hour            327346 non-null  int8
#  18  minute          327346 non-null  int8
#  19  time_hour       327346 non-null  object
#  20  name            327346 non-null  category
#  21  cancelled       327346 non-null  int64
#  22  flight_date     327346 non-null  datetime64[ns]
#  23  day_of_week     327346 non-null  object
#  24  route           327346 non-null  object
#  25  on_time         327346 non-null  int64
# dtypes: category(5), datetime64[ns](1), float32(3), float64(2), int16(2), int64(6), int8(4), object(3)
# memory usage: 89.7 MB
